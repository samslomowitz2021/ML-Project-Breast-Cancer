# %%
# generic data science libraries
import pandas as pd
pd.set_option('display.max_columns', None)
import numpy as np

# data visualization
import matplotlib.pyplot as plt
import seaborn as sns

# import scikit-learn
from sklearn.model_selection import train_test_split

# models
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from xgboost import XGBClassifier

# metrics
from sklearn.metrics import accuracy_score, classification_report, auc, confusion_matrix, roc_curve

# %%
df = pd.read_csv("Final_Clean.csv")
df
# Out:
#      Unnamed: 0  diagnosis concave_points_worst_bins perimeter_worst_bins  \
# 0             0          1                         D                    D
# 1             1          1                         D                    D
# 2             2          1                         D                    D
# 3             3          1                         D                    C
# 4             4          1                         D                    D
# ..          ...        ...                       ...                  ...
# 564         564          1                         D                    D
# 565         565          1                         D                    D
# 566         566          1                         C                    D
# 567         567          1                         D                    D
# 568         568          0                         A                    A
#
#     concave_points_mean_bins radius_worst_bins  perimeter_mean  area_worst  \
# 0                          D                 D          122.80      2019.0
# 1                          C                 D          132.90      1956.0
# 2                          D                 D          130.00      1709.0
# 3                          D                 B           77.58       567.7
# 4                          D                 D          135.10      1575.0
# ..                       ...               ...             ...         ...
# 564                        D                 D          142.00      2027.0
# 565                        D                 D          131.20      1731.0
# 566                        C                 C          108.30      1124.0
# 567                        D                 D          140.10      1821.0
# 568                        A                 A           47.92       268.6
#
#      radius_mean  area_mean
# 0          17.99     1001.0
# 1          20.57     1326.0
# 2          19.69     1203.0
# 3          11.42      386.1
# 4          20.29     1297.0
# ..           ...        ...
# 564        21.56     1479.0
# 565        20.13     1261.0
# 566        16.60      858.1
# 567        20.60     1265.0
# 568         7.76      181.0
#
# [569 rows x 10 columns]

# %%
df2 = df.drop(columns=['Unnamed: 0'])
df2
# Out:
#      diagnosis concave_points_worst_bins perimeter_worst_bins  \
# 0            1                         D                    D
# 1            1                         D                    D
# 2            1                         D                    D
# 3            1                         D                    C
# 4            1                         D                    D
# ..         ...                       ...                  ...
# 564          1                         D                    D
# 565          1                         D                    D
# 566          1                         C                    D
# 567          1                         D                    D
# 568          0                         A                    A
#
#     concave_points_mean_bins radius_worst_bins  perimeter_mean  area_worst  \
# 0                          D                 D          122.80      2019.0
# 1                          C                 D          132.90      1956.0
# 2                          D                 D          130.00      1709.0
# 3                          D                 B           77.58       567.7
# 4                          D                 D          135.10      1575.0
# ..                       ...               ...             ...         ...
# 564                        D                 D          142.00      2027.0
# 565                        D                 D          131.20      1731.0
# 566                        C                 C          108.30      1124.0
# 567                        D                 D          140.10      1821.0
# 568                        A                 A           47.92       268.6
#
#      radius_mean  area_mean
# 0          17.99     1001.0
# 1          20.57     1326.0
# 2          19.69     1203.0
# 3          11.42      386.1
# 4          20.29     1297.0
# ..           ...        ...
# 564        21.56     1479.0
# 565        20.13     1261.0
# 566        16.60      858.1
# 567        20.60     1265.0
# 568         7.76      181.0
#
# [569 rows x 9 columns]

# %%
df2.describe()
# Out:
#         diagnosis  perimeter_mean   area_worst  radius_mean    area_mean
# count  569.000000      569.000000   569.000000   569.000000   569.000000
# mean     0.372583       91.969033   880.583128    14.127292   654.889104
# std      0.483918       24.298981   569.356993     3.524049   351.914129
# min      0.000000       43.790000   185.200000     6.981000   143.500000
# 25%      0.000000       75.170000   515.300000    11.700000   420.300000
# 50%      0.000000       86.240000   686.500000    13.370000   551.100000
# 75%      1.000000      104.100000  1084.000000    15.780000   782.700000
# max      1.000000      188.500000  4254.000000    28.110000  2501.000000

# %%
# Create bins in which to place values based upon TED Talk views
bins = [43, 75, 86,104, 99999999]

# Create labels for these bins
group_labels = ["A", "B","C","D"]

df2['perimeter_mean_bins'] = pd.cut(df2['perimeter_mean'], bins, labels=group_labels, include_lowest=True)
df2.head()
# Out:
#    diagnosis concave_points_worst_bins perimeter_worst_bins  \
# 0          1                         D                    D
# 1          1                         D                    D
# 2          1                         D                    D
# 3          1                         D                    C
# 4          1                         D                    D
#
#   concave_points_mean_bins radius_worst_bins  perimeter_mean  area_worst  \
# 0                        D                 D          122.80      2019.0
# 1                        C                 D          132.90      1956.0
# 2                        D                 D          130.00      1709.0
# 3                        D                 B           77.58       567.7
# 4                        D                 D          135.10      1575.0
#
#    radius_mean  area_mean perimeter_mean_bins
# 0        17.99     1001.0                   D
# 1        20.57     1326.0                   D
# 2        19.69     1203.0                   D
# 3        11.42      386.1                   B
# 4        20.29     1297.0                   D

# %%
df3=df2.drop(columns=['perimeter_mean'])
df3.head()
# Out:
#    diagnosis concave_points_worst_bins perimeter_worst_bins  \
# 0          1                         D                    D
# 1          1                         D                    D
# 2          1                         D                    D
# 3          1                         D                    C
# 4          1                         D                    D
#
#   concave_points_mean_bins radius_worst_bins  area_worst  radius_mean  \
# 0                        D                 D      2019.0        17.99
# 1                        C                 D      1956.0        20.57
# 2                        D                 D      1709.0        19.69
# 3                        D                 B       567.7        11.42
# 4                        D                 D      1575.0        20.29
#
#    area_mean perimeter_mean_bins
# 0     1001.0                   D
# 1     1326.0                   D
# 2     1203.0                   D
# 3      386.1                   B
# 4     1297.0                   D

# %%
# Create bins in which to place values based upon TED Talk views
bins = [185, 515, 696,1084, 99999999]

# Create labels for these bins
group_labels = ["A", "B","C","D"]

df3['area_worst_bins'] = pd.cut(df3['area_worst'], bins, labels=group_labels, include_lowest=True)
df3.head()
# Out:
#    diagnosis concave_points_worst_bins perimeter_worst_bins  \
# 0          1                         D                    D
# 1          1                         D                    D
# 2          1                         D                    D
# 3          1                         D                    C
# 4          1                         D                    D
#
#   concave_points_mean_bins radius_worst_bins  area_worst  radius_mean  \
# 0                        D                 D      2019.0        17.99
# 1                        C                 D      1956.0        20.57
# 2                        D                 D      1709.0        19.69
# 3                        D                 B       567.7        11.42
# 4                        D                 D      1575.0        20.29
#
#    area_mean perimeter_mean_bins area_worst_bins
# 0     1001.0                   D               D
# 1     1326.0                   D               D
# 2     1203.0                   D               D
# 3      386.1                   B               B
# 4     1297.0                   D               D

# %%
df4=df3.drop(columns=['area_worst'])
df4.head()
# Out:
#    diagnosis concave_points_worst_bins perimeter_worst_bins  \
# 0          1                         D                    D
# 1          1                         D                    D
# 2          1                         D                    D
# 3          1                         D                    C
# 4          1                         D                    D
#
#   concave_points_mean_bins radius_worst_bins  radius_mean  area_mean  \
# 0                        D                 D        17.99     1001.0
# 1                        C                 D        20.57     1326.0
# 2                        D                 D        19.69     1203.0
# 3                        D                 B        11.42      386.1
# 4                        D                 D        20.29     1297.0
#
#   perimeter_mean_bins area_worst_bins
# 0                   D               D
# 1                   D               D
# 2                   D               D
# 3                   B               B
# 4                   D               D

# %%
# Create bins in which to place values based upon TED Talk views
bins = [6, 12, 14,16, 99999999]

# Create labels for these bins
group_labels = ["A", "B","C","D"]

df4['radius_mean_bins'] = pd.cut(df4['radius_mean'], bins, labels=group_labels, include_lowest=True)
df4.head()
# Out:
#    diagnosis concave_points_worst_bins perimeter_worst_bins  \
# 0          1                         D                    D
# 1          1                         D                    D
# 2          1                         D                    D
# 3          1                         D                    C
# 4          1                         D                    D
#
#   concave_points_mean_bins radius_worst_bins  radius_mean  area_mean  \
# 0                        D                 D        17.99     1001.0
# 1                        C                 D        20.57     1326.0
# 2                        D                 D        19.69     1203.0
# 3                        D                 B        11.42      386.1
# 4                        D                 D        20.29     1297.0
#
#   perimeter_mean_bins area_worst_bins radius_mean_bins
# 0                   D               D                D
# 1                   D               D                D
# 2                   D               D                D
# 3                   B               B                A
# 4                   D               D                D

# %%
df5=df4.drop(columns=['radius_mean'])
df5.head()
# Out:
#    diagnosis concave_points_worst_bins perimeter_worst_bins  \
# 0          1                         D                    D
# 1          1                         D                    D
# 2          1                         D                    D
# 3          1                         D                    C
# 4          1                         D                    D
#
#   concave_points_mean_bins radius_worst_bins  area_mean perimeter_mean_bins  \
# 0                        D                 D     1001.0                   D
# 1                        C                 D     1326.0                   D
# 2                        D                 D     1203.0                   D
# 3                        D                 B      386.1                   B
# 4                        D                 D     1297.0                   D
#
#   area_worst_bins radius_mean_bins
# 0               D                D
# 1               D                D
# 2               D                D
# 3               B                A
# 4               D                D

# %%
# Create bins in which to place values based upon TED Talk views
bins = [143, 420, 551,782, 99999999]

# Create labels for these bins
group_labels = ["A", "B","C","D"]

df5['area_mean_bins'] = pd.cut(df5['area_mean'], bins, labels=group_labels, include_lowest=True)
df5.head()
# Out:
#    diagnosis concave_points_worst_bins perimeter_worst_bins  \
# 0          1                         D                    D
# 1          1                         D                    D
# 2          1                         D                    D
# 3          1                         D                    C
# 4          1                         D                    D
#
#   concave_points_mean_bins radius_worst_bins  area_mean perimeter_mean_bins  \
# 0                        D                 D     1001.0                   D
# 1                        C                 D     1326.0                   D
# 2                        D                 D     1203.0                   D
# 3                        D                 B      386.1                   B
# 4                        D                 D     1297.0                   D
#
#   area_worst_bins radius_mean_bins area_mean_bins
# 0               D                D              D
# 1               D                D              D
# 2               D                D              D
# 3               B                A              A
# 4               D                D              D

# %%
df6=df5.drop(columns=['area_mean'])
df6.head()
# Out:
#    diagnosis concave_points_worst_bins perimeter_worst_bins  \
# 0          1                         D                    D
# 1          1                         D                    D
# 2          1                         D                    D
# 3          1                         D                    C
# 4          1                         D                    D
#
#   concave_points_mean_bins radius_worst_bins perimeter_mean_bins  \
# 0                        D                 D                   D
# 1                        C                 D                   D
# 2                        D                 D                   D
# 3                        D                 B                   B
# 4                        D                 D                   D
#
#   area_worst_bins radius_mean_bins area_mean_bins
# 0               D                D              D
# 1               D                D              D
# 2               D                D              D
# 3               B                A              A
# 4               D                D              D

# %%
df6.to_csv("Final_Clean2.csv")
