# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
from scipy.stats import linregress
import seaborn as sns

# IMPORTS
# data science libraries
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd

# loading linear algorithms
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC 

# tree based algorithms
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier, ExtraTreesClassifier, GradientBoostingClassifier
from lightgbm import LGBMClassifier
from xgboost import XGBClassifier

# machine learning processing and metrics
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, MinMaxScaler, LabelEncoder
from sklearn.metrics import classification_report, confusion_matrix, roc_auc_score, roc_curve
from sklearn.metrics import accuracy_score, classification_report, auc, confusion_matrix, roc_curve

file = pd.read_csv("../data/data.csv")

file.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#    ...  texture_worst  perimeter_worst  area_worst  smoothness_worst  \
# 0  ...          17.33           184.60      2019.0            0.1622
# 1  ...          23.41           158.80      1956.0            0.1238
# 2  ...          25.53           152.50      1709.0            0.1444
# 3  ...          26.50            98.87       567.7            0.2098
# 4  ...          16.67           152.20      1575.0            0.1374
#
#    compactness_worst  concavity_worst  concave points_worst  symmetry_worst  \
# 0             0.6656           0.7119                0.2654          0.4601
# 1             0.1866           0.2416                0.1860          0.2750
# 2             0.4245           0.4504                0.2430          0.3613
# 3             0.8663           0.6869                0.2575          0.6638
# 4             0.2050           0.4000                0.1625          0.2364
#
#    fractal_dimension_worst  Unnamed: 32
# 0                  0.11890          NaN
# 1                  0.08902          NaN
# 2                  0.08758          NaN
# 3                  0.17300          NaN
# 4                  0.07678          NaN
#
# [5 rows x 33 columns]

# %%
file = pd.read_csv("cleaned_data_8_25.csv")

file.head()

# %%
df600 = file.drop(columns=['Unnamed: 0'])
df600.columns

# %%
file.columns

# %%
file.diagnosis.value_counts()

# %%
file.info()

# %%
df2 = df.drop(columns=['id'])

# %%
df2

# %%
#df2.rename(columns={"A": "a", "B": "c"})

# %%
df2.describe()

# %%
# Create bins in which to place values based upon TED Talk views
bins = [143.500000, 420.300000, 551.100000,782.700000, 99999999]

# Create labels for these bins
group_labels = ["Low", "Medium_Low","Medium_High","High"]

df2['area_mean_bins'] = pd.cut(df2['area_mean'], bins, labels=group_labels, include_lowest=True)
df2.head()
# Out:
#   diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0         M        17.99         10.38          122.80     1001.0
# 1         M        20.57         17.77          132.90     1326.0
# 2         M        19.69         21.25          130.00     1203.0
# 3         M        11.42         20.38           77.58      386.1
# 4         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#    symmetry_mean  ...  texture_worst  perimeter_worst  area_worst  \
# 0         0.2419  ...          17.33           184.60      2019.0
# 1         0.1812  ...          23.41           158.80      1956.0
# 2         0.2069  ...          25.53           152.50      1709.0
# 3         0.2597  ...          26.50            98.87       567.7
# 4         0.1809  ...          16.67           152.20      1575.0
#
#    smoothness_worst  compactness_worst  concavity_worst  concave points_worst  \
# 0            0.1622             0.6656           0.7119                0.2654
# 1            0.1238             0.1866           0.2416                0.1860
# 2            0.1444             0.4245           0.4504                0.2430
# 3            0.2098             0.8663           0.6869                0.2575
# 4            0.1374             0.2050           0.4000                0.1625
#
#    symmetry_worst  fractal_dimension_worst  area_mean_bins
# 0          0.4601                  0.11890            High
# 1          0.2750                  0.08902            High
# 2          0.3613                  0.08758            High
# 3          0.6638                  0.17300             Low
# 4          0.2364                  0.07678            High
#
# [5 rows x 32 columns]

# %%
df2.head()

# %%
df2.info()

# %%
df3=df2.drop(columns=['concave points_worst', 
'perimeter_worst',
'concave points_mean', 
'radius_worst', 
'perimeter_mean', 
'area_worst',
'radius_mean',
'area_mean'])
df3.head()
# Out:
#   diagnosis  texture_mean  smoothness_mean  compactness_mean  concavity_mean  \
# 0         M         10.38          0.11840           0.27760          0.3001
# 1         M         17.77          0.08474           0.07864          0.0869
# 2         M         21.25          0.10960           0.15990          0.1974
# 3         M         20.38          0.14250           0.28390          0.2414
# 4         M         14.34          0.10030           0.13280          0.1980
#
#    symmetry_mean  fractal_dimension_mean  radius_se  texture_se  perimeter_se  \
# 0         0.2419                 0.07871     1.0950      0.9053         8.589
# 1         0.1812                 0.05667     0.5435      0.7339         3.398
# 2         0.2069                 0.05999     0.7456      0.7869         4.585
# 3         0.2597                 0.09744     0.4956      1.1560         3.445
# 4         0.1809                 0.05883     0.7572      0.7813         5.438
#
#    ...  symmetry_worst  fractal_dimension_worst  area_mean_bins  \
# 0  ...          0.4601                  0.11890            High
# 1  ...          0.2750                  0.08902            High
# 2  ...          0.3613                  0.08758            High
# 3  ...          0.6638                  0.17300             Low
# 4  ...          0.2364                  0.07678            High
#
#    area_worst_bins  perimeter_mean_bins  radius_worst_bins  \
# 0             High                 High               High
# 1             High                 High               High
# 2             High                 High               High
# 3       Medium_Low           Medium_Low         Medium_Low
# 4             High                 High               High
#
#    concave_points_mean_bins  perimeter_worst_bins  concave points_worst_bins  \
# 0                      High                  High                       High
# 1               Medium_High                  High                       High
# 2                      High                  High                       High
# 3                      High           Medium_High                       High
# 4                      High                  High                       High
#
#    radius_mean_bins
# 0              High
# 1              High
# 2              High
# 3               Low
# 4              High
#
# [5 rows x 31 columns]

# %%
df3

# %%
df3.columns

# %%
df95 = df3.loc[:, ['diagnosis','radius_worst_bins',
       'concave_points_mean_bins', 'perimeter_worst_bins',
       'concave points_worst_bins', 'radius_mean_bins', 'perimeter_mean_bins',
       'area_worst_bins', 'area_mean_bins']]
df95.head()
# Out:
#   diagnosis radius_worst_bins concave_points_mean_bins perimeter_worst_bins  \
# 0         M              High                     High                 High
# 1         M              High              Medium_High                 High
# 2         M              High                     High                 High
# 3         M        Medium_Low                     High          Medium_High
# 4         M              High                     High                 High
#
#   concave points_worst_bins radius_mean_bins perimeter_mean_bins  \
# 0                      High             High                High
# 1                      High             High                High
# 2                      High             High                High
# 3                      High              Low          Medium_Low
# 4                      High             High                High
#
#   area_worst_bins area_mean_bins
# 0            High           High
# 1            High           High
# 2            High           High
# 3      Medium_Low            Low
# 4            High           High

# %%
df95.shape
# Out:
# (569, 9)

# %%
df95.to_csv('version10.csv')

# %%
# Create bins in which to place values based upon TED Talk views
bins = [185.200000, 515.300000, 686.500000,1084.000000, 99999999]

# Create labels for these bins
group_labels = ["Low", "Medium_Low","Medium_High","High"]

df2['area_worst_bins'] = pd.cut(df2['area_worst'], bins, labels=group_labels, include_lowest=True)
df2.head()
# Out:
#   diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0         M        17.99         10.38          122.80     1001.0
# 1         M        20.57         17.77          132.90     1326.0
# 2         M        19.69         21.25          130.00     1203.0
# 3         M        11.42         20.38           77.58      386.1
# 4         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#    symmetry_mean  ...  perimeter_worst  area_worst  smoothness_worst  \
# 0         0.2419  ...           184.60      2019.0            0.1622
# 1         0.1812  ...           158.80      1956.0            0.1238
# 2         0.2069  ...           152.50      1709.0            0.1444
# 3         0.2597  ...            98.87       567.7            0.2098
# 4         0.1809  ...           152.20      1575.0            0.1374
#
#    compactness_worst  concavity_worst  concave points_worst  symmetry_worst  \
# 0             0.6656           0.7119                0.2654          0.4601
# 1             0.1866           0.2416                0.1860          0.2750
# 2             0.4245           0.4504                0.2430          0.3613
# 3             0.8663           0.6869                0.2575          0.6638
# 4             0.2050           0.4000                0.1625          0.2364
#
#    fractal_dimension_worst  area_mean_bins  area_worst_bins
# 0                  0.11890            High             High
# 1                  0.08902            High             High
# 2                  0.08758            High             High
# 3                  0.17300             Low       Medium_Low
# 4                  0.07678            High             High
#
# [5 rows x 33 columns]

# %%
# Create bins in which to place values based upon TED Talk views
bins = [43.790000, 75.170000, 86.240000,104.100000, 99999999]

# Create labels for these bins
group_labels = ["Low", "Medium_Low","Medium_High","High"]

df2['perimeter_mean_bins'] = pd.cut(df2['perimeter_mean'], bins, labels=group_labels, include_lowest=True)
df2.head()
# Out:
#   diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0         M        17.99         10.38          122.80     1001.0
# 1         M        20.57         17.77          132.90     1326.0
# 2         M        19.69         21.25          130.00     1203.0
# 3         M        11.42         20.38           77.58      386.1
# 4         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#    symmetry_mean  ...  area_worst  smoothness_worst  compactness_worst  \
# 0         0.2419  ...      2019.0            0.1622             0.6656
# 1         0.1812  ...      1956.0            0.1238             0.1866
# 2         0.2069  ...      1709.0            0.1444             0.4245
# 3         0.2597  ...       567.7            0.2098             0.8663
# 4         0.1809  ...      1575.0            0.1374             0.2050
#
#    concavity_worst  concave points_worst  symmetry_worst  \
# 0           0.7119                0.2654          0.4601
# 1           0.2416                0.1860          0.2750
# 2           0.4504                0.2430          0.3613
# 3           0.6869                0.2575          0.6638
# 4           0.4000                0.1625          0.2364
#
#    fractal_dimension_worst  area_mean_bins  area_worst_bins  \
# 0                  0.11890            High             High
# 1                  0.08902            High             High
# 2                  0.08758            High             High
# 3                  0.17300             Low       Medium_Low
# 4                  0.07678            High             High
#
#    perimeter_mean_bins
# 0                 High
# 1                 High
# 2                 High
# 3           Medium_Low
# 4                 High
#
# [5 rows x 34 columns]

# %%
# Create bins in which to place values based upon TED Talk views
bins = [0, 13, 15,19, 99999999]

# Create labels for these bins
group_labels = ["Low", "Medium_Low","Medium_High","High"]

df2['radius_worst_bins'] = pd.cut(df2['radius_worst'], bins, labels=group_labels, include_lowest=True)
df2.head()
# Out:
#   diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0         M        17.99         10.38          122.80     1001.0
# 1         M        20.57         17.77          132.90     1326.0
# 2         M        19.69         21.25          130.00     1203.0
# 3         M        11.42         20.38           77.58      386.1
# 4         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#    symmetry_mean  ...  smoothness_worst  compactness_worst  concavity_worst  \
# 0         0.2419  ...            0.1622             0.6656           0.7119
# 1         0.1812  ...            0.1238             0.1866           0.2416
# 2         0.2069  ...            0.1444             0.4245           0.4504
# 3         0.2597  ...            0.2098             0.8663           0.6869
# 4         0.1809  ...            0.1374             0.2050           0.4000
#
#    concave points_worst  symmetry_worst  fractal_dimension_worst  \
# 0                0.2654          0.4601                  0.11890
# 1                0.1860          0.2750                  0.08902
# 2                0.2430          0.3613                  0.08758
# 3                0.2575          0.6638                  0.17300
# 4                0.1625          0.2364                  0.07678
#
#    area_mean_bins  area_worst_bins  perimeter_mean_bins  radius_worst_bins
# 0            High             High                 High               High
# 1            High             High                 High               High
# 2            High             High                 High               High
# 3             Low       Medium_Low           Medium_Low         Medium_Low
# 4            High             High                 High               High
#
# [5 rows x 35 columns]

# %%
# Create bins in which to place values based upon TED Talk views
bins = [0.000000, 0.020310, 0.033500,0.074000, 99999999]

# Create labels for these bins
group_labels = ["Low", "Medium_Low","Medium_High","High"]

df2["concave_points_mean_bins"] = pd.cut(df2["concave points_mean"], bins, labels=group_labels, include_lowest=True)
df2.head()
# Out:
#   diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0         M        17.99         10.38          122.80     1001.0
# 1         M        20.57         17.77          132.90     1326.0
# 2         M        19.69         21.25          130.00     1203.0
# 3         M        11.42         20.38           77.58      386.1
# 4         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#    symmetry_mean  ...  compactness_worst  concavity_worst  \
# 0         0.2419  ...             0.6656           0.7119
# 1         0.1812  ...             0.1866           0.2416
# 2         0.2069  ...             0.4245           0.4504
# 3         0.2597  ...             0.8663           0.6869
# 4         0.1809  ...             0.2050           0.4000
#
#    concave points_worst  symmetry_worst  fractal_dimension_worst  \
# 0                0.2654          0.4601                  0.11890
# 1                0.1860          0.2750                  0.08902
# 2                0.2430          0.3613                  0.08758
# 3                0.2575          0.6638                  0.17300
# 4                0.1625          0.2364                  0.07678
#
#    area_mean_bins  area_worst_bins  perimeter_mean_bins  radius_worst_bins  \
# 0            High             High                 High               High
# 1            High             High                 High               High
# 2            High             High                 High               High
# 3             Low       Medium_Low           Medium_Low         Medium_Low
# 4            High             High                 High               High
#
#    concave_points_mean_bins
# 0                      High
# 1               Medium_High
# 2                      High
# 3                      High
# 4                      High
#
# [5 rows x 36 columns]

# %%
# Create bins in which to place values based upon TED Talk views
bins = [50.410000, 84.110000, 97.660000,125.400000, 99999999]

# Create labels for these bins
group_labels = ["Low", "Medium_Low","Medium_High","High"]

df2["perimeter_worst_bins"] = pd.cut(df2["perimeter_worst"], bins, labels=group_labels, include_lowest=True)
df2.head()
# Out:
#   diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0         M        17.99         10.38          122.80     1001.0
# 1         M        20.57         17.77          132.90     1326.0
# 2         M        19.69         21.25          130.00     1203.0
# 3         M        11.42         20.38           77.58      386.1
# 4         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#    symmetry_mean  ...  concavity_worst  concave points_worst  symmetry_worst  \
# 0         0.2419  ...           0.7119                0.2654          0.4601
# 1         0.1812  ...           0.2416                0.1860          0.2750
# 2         0.2069  ...           0.4504                0.2430          0.3613
# 3         0.2597  ...           0.6869                0.2575          0.6638
# 4         0.1809  ...           0.4000                0.1625          0.2364
#
#    fractal_dimension_worst  area_mean_bins  area_worst_bins  \
# 0                  0.11890            High             High
# 1                  0.08902            High             High
# 2                  0.08758            High             High
# 3                  0.17300             Low       Medium_Low
# 4                  0.07678            High             High
#
#    perimeter_mean_bins  radius_worst_bins  concave_points_mean_bins  \
# 0                 High               High                      High
# 1                 High               High               Medium_High
# 2                 High               High                      High
# 3           Medium_Low         Medium_Low                      High
# 4                 High               High                      High
#
#    perimeter_worst_bins
# 0                  High
# 1                  High
# 2                  High
# 3           Medium_High
# 4                  High
#
# [5 rows x 37 columns]

# %%
# Create bins in which to place values based upon TED Talk views
bins = [0, 0.064930, 0.099930, 0.161400, 99999999]

# Create labels for these bins
group_labels = ["Low", "Medium_Low","Medium_High","High"]

df2["concave points_worst_bins"] = pd.cut(df2["concave points_worst"], bins, labels=group_labels, include_lowest=True)
df2.head()
# Out:
#   diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0         M        17.99         10.38          122.80     1001.0
# 1         M        20.57         17.77          132.90     1326.0
# 2         M        19.69         21.25          130.00     1203.0
# 3         M        11.42         20.38           77.58      386.1
# 4         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#    symmetry_mean  ...  concave points_worst  symmetry_worst  \
# 0         0.2419  ...                0.2654          0.4601
# 1         0.1812  ...                0.1860          0.2750
# 2         0.2069  ...                0.2430          0.3613
# 3         0.2597  ...                0.2575          0.6638
# 4         0.1809  ...                0.1625          0.2364
#
#    fractal_dimension_worst  area_mean_bins  area_worst_bins  \
# 0                  0.11890            High             High
# 1                  0.08902            High             High
# 2                  0.08758            High             High
# 3                  0.17300             Low       Medium_Low
# 4                  0.07678            High             High
#
#    perimeter_mean_bins  radius_worst_bins  concave_points_mean_bins  \
# 0                 High               High                      High
# 1                 High               High               Medium_High
# 2                 High               High                      High
# 3           Medium_Low         Medium_Low                      High
# 4                 High               High                      High
#
#    perimeter_worst_bins  concave points_worst_bins
# 0                  High                       High
# 1                  High                       High
# 2                  High                       High
# 3           Medium_High                       High
# 4                  High                       High
#
# [5 rows x 38 columns]

# %%
# Create bins in which to place values based upon TED Talk views
bins = [6, 11.7, 13.37, 15.78, 99999999]

# Create labels for these bins
group_labels = ["Low", "Medium_Low","Medium_High","High"]

# %%
df2["radius_mean_bins"] = pd.cut(df2.radius_mean, bins, labels=group_labels, include_lowest=True)
df2.head()
# Out:
#   diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0         M        17.99         10.38          122.80     1001.0
# 1         M        20.57         17.77          132.90     1326.0
# 2         M        19.69         21.25          130.00     1203.0
# 3         M        11.42         20.38           77.58      386.1
# 4         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#    symmetry_mean  ...  symmetry_worst  fractal_dimension_worst  \
# 0         0.2419  ...          0.4601                  0.11890
# 1         0.1812  ...          0.2750                  0.08902
# 2         0.2069  ...          0.3613                  0.08758
# 3         0.2597  ...          0.6638                  0.17300
# 4         0.1809  ...          0.2364                  0.07678
#
#    area_mean_bins  area_worst_bins  perimeter_mean_bins  radius_worst_bins  \
# 0            High             High                 High               High
# 1            High             High                 High               High
# 2            High             High                 High               High
# 3             Low       Medium_Low           Medium_Low         Medium_Low
# 4            High             High                 High               High
#
#    concave_points_mean_bins  perimeter_worst_bins  concave points_worst_bins  \
# 0                      High                  High                       High
# 1               Medium_High                  High                       High
# 2                      High                  High                       High
# 3                      High           Medium_High                       High
# 4                      High                  High                       High
#
#    radius_mean_bins
# 0              High
# 1              High
# 2              High
# 3               Low
# 4              High
#
# [5 rows x 39 columns]

# %%
'perimeter_mean', 'area_worst',
'area_mean', 'concavity_mean', 'concavity_worst',
'compactness_mean', 'compactness_worst', 'radius_se', 'perimeter_se',
'area_se'

# %%
#'concave points_worst', 
#'perimeter_worst',
#'concave points_mean', 
#'radius_worst', 
#'perimeter_mean', 
#'area_worst',
#'radius_mean',
#'area_mean', 
'concavity_mean', 
'concavity_worst',
'compactness_mean', 
'compactness_worst', 
'radius_se', 
'perimeter_se',
'area_se'

# %%
df2.to_csv('cleaned_data_8_25.csv')

# %%
df_le = df2.loc[:, ["diagnosis"]]
df_le["diagnosis"] = [1 if x == "M" else 0 for x in df_le.diagnosis]
df_le.head()

# %%
num_cols = []

for col in df2.columns:
    if (df2[col].dtype == "float64"):
        print(col)
        num_cols.append(col)
        
df_num = df2.loc[:, num_cols]
df_num.head()

# %%
df_scale=df_num

# %%
#d scale training set
df_scale2 = pd.concat([df_scale, df_le], axis=1)
df_scale2

# %%
corrs = abs(df_scale2.corr())["diagnosis"].sort_values(ascending=False)
corrs

# %%
corrs.index

# %%
# LOW correlations <.50
cols_to_drop = ['texture_worst', 'smoothness_worst', 'symmetry_worst',
       'texture_mean', 'concave points_se', 'smoothness_mean', 'symmetry_mean',
       'fractal_dimension_worst', 'compactness_se', 'concavity_se',
       'fractal_dimension_se', 'smoothness_se', 'fractal_dimension_mean',
       'texture_se', 'symmetry_se']

cols_keep = [x for x in df_scale2 if x not in cols_to_drop]
df_scale3 = df_scale2.loc[:, cols_keep]
df_scale3.head()

# %%
X = df_scale3.loc[:, ['concave points_worst', 'perimeter_worst',
       'concave points_mean', 'radius_worst', 'perimeter_mean', 'area_worst',
       'radius_mean', 'area_mean', 'concavity_mean', 'concavity_worst',
       'compactness_mean', 'compactness_worst', 'radius_se', 'perimeter_se',
       'area_se']].values
y = df_scale3["diagnosis"].values

# %%
# Use the Sklearn `train_test_split()` function to split the data into training and testing data
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=23, test_size=.25, stratify=y)

print(len(X_train) / len(X))
print(len(X_test) / len(X))

# %%
# Initialize the model
model1 = LogisticRegression()

# FIT THE MODEL
model1.fit(X_train, y_train)

# EVALUATE the MODEL
train_preds = model1.predict(X_train)
test_preds = model1.predict(X_test)

# PRINT the METRICS
print("TRAINING SET")

class_report_train = classification_report(y_train, train_preds)
conf_matrix_train = confusion_matrix(y_train, train_preds)

print(class_report_train)
print(conf_matrix_train)

print()

# PRINT the METRICS
print("Testing SET")

class_report_test = classification_report(y_test, test_preds)
conf_matrix_test = confusion_matrix(y_test, test_preds)

print(class_report_test)
print(conf_matrix_test)

# %%
y_pred_proba = model1.predict_proba(X_test)[::,1]
fpr, tpr, _ = roc_curve(y_test,  y_pred_proba)
auc = roc_auc_score(y_test, y_pred_proba)

plt.figure(figsize=(10,6))
plt.plot(fpr,tpr,label="auc="+str(auc))
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("ROC Curve Test Set")
plt.legend(loc=4)
plt.show()

# %%
# Initialize the model
model2 = KNeighborsClassifier(n_neighbors=5)

# FIT THE MODEL
model2.fit(X_train, y_train)

# EVALUATE the MODEL
train_preds = model2.predict(X_train)
test_preds = model2.predict(X_test)

# PRINT the METRICS
print("TRAINING SET")

class_report_train = classification_report(y_train, train_preds)
conf_matrix_train = confusion_matrix(y_train, train_preds)

print(class_report_train)
print(conf_matrix_train)

print()

# PRINT the METRICS
print("Testing SET")

class_report_test = classification_report(y_test, test_preds)
conf_matrix_test = confusion_matrix(y_test, test_preds)

print(class_report_test)
print(conf_matrix_test)

# %%
y_pred_proba = model2.predict_proba(X_test)[::,1]
fpr, tpr, _ = roc_curve(y_test,  y_pred_proba)
auc = roc_auc_score(y_test, y_pred_proba)

plt.figure(figsize=(10,6))
plt.plot(fpr,tpr,label="auc="+str(auc))
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("ROC Curve Test Set")
plt.legend(loc=4)
plt.show()

# %%
# Initialize the model
model3 = SVC(probability=True)

# FIT THE MODEL
model3.fit(X_train, y_train)

# EVALUATE the MODEL
train_preds = model3.predict(X_train)
test_preds = model3.predict(X_test)

# PRINT the METRICS
print("TRAINING SET")

class_report_train = classification_report(y_train, train_preds)
conf_matrix_train = confusion_matrix(y_train, train_preds)

print(class_report_train)
print(conf_matrix_train)

print()

# PRINT the METRICS
print("Testing SET")

class_report_test = classification_report(y_test, test_preds)
conf_matrix_test = confusion_matrix(y_test, test_preds)

print(class_report_test)
print(conf_matrix_test)

# %%
y_pred_proba = model3.predict_proba(X_test)[::,1]
fpr, tpr, _ = roc_curve(y_test,  y_pred_proba)
auc = roc_auc_score(y_test, y_pred_proba)

plt.figure(figsize=(10,6))
plt.plot(fpr,tpr,label="auc="+str(auc))
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("ROC Curve Test Set")
plt.legend(loc=4)
plt.show()

# %%
# Initialize the model
model4 = RandomForestClassifier()

# FIT THE MODEL
model4.fit(X_train, y_train)

# EVALUATE the MODEL
train_preds = model4.predict(X_train)
test_preds = model4.predict(X_test)

# PRINT the METRICS
print("TRAINING SET")

class_report_train = classification_report(y_train, train_preds)
conf_matrix_train = confusion_matrix(y_train, train_preds)

print(class_report_train)
print(conf_matrix_train)

print()

# PRINT the METRICS
print("Testing SET")

class_report_test = classification_report(y_test, test_preds)
conf_matrix_test = confusion_matrix(y_test, test_preds)

print(class_report_test)
print(conf_matrix_test)

# %%
y_pred_proba = model4.predict_proba(X_test)[::,1]
fpr, tpr, _ = roc_curve(y_test,  y_pred_proba)
auc = roc_auc_score(y_test, y_pred_proba)

plt.figure(figsize=(10,6))
plt.plot(fpr,tpr,label="auc="+str(auc))
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("ROC Curve Test Set")
plt.legend(loc=4)
plt.show()
